# %% [raw]
# ---
# output-file: helpers.html
# title: Helpers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## General functions

# %% [markdown]
# This are prewritten functions by KIMN.

# %%
#| echo: false
#| output: asis
show_doc(tool_is_present)
# Out:
# ---
#
# ### tool_is_present
#
# >      tool_is_present (tool_name:str)
#
# This function check for programs reliant
# on other tools that the tool is present.

# %%
#| echo: false
#| output: asis
show_doc(tools_are_present)
# Out:
# ---
#
# ### tools_are_present
#
# >      tools_are_present (tool_names:list)
#
# This function checks for a list of programs
# reliant on other tools that the tool is present.

# %%
# import subprocess
# if not core.tools_are_present([tool]):
#     process = subprocess.Popen(f"conda install -c bioconda {tool}".split(" "), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#     process.communicate()
#     if not core.tool_is_present(tool):
#         raise ImportError(f"{tool} not installed")

# %%
#| echo: false
#| output: asis
show_doc(notification)
# Out:
# ---
#
# ### notification
#
# >      notification (notification:dict)
#
# This function sends a notification to the user.

# %%
#| echo: false
#| output: asis
show_doc(write_list_to_file)
# Out:
# ---
#
# ### write_list_to_file
#
# >      write_list_to_file (content:list[str], file_path:str, overwrite=True,
# >                          to_stdout=False)
#
# This function takes a list of commands and put it to a file.
# This can be manipulated for wrapping in a resource manager.

# %%
#| echo: false
#| output: asis
show_doc(execute_commands_from_file)
# Out:
# ---
#
# ### execute_commands_from_file
#
# >      execute_commands_from_file (command_file_path:str)
#
# This function executes commands from a file.

# %%
#| echo: false
#| output: asis
show_doc(get_experiment_name)
# Out:
# ---
#
# ### get_experiment_name
#
# >      get_experiment_name (sample_sheet_path:pathlib.Path)
#
# This function parses a sample sheet
# to find the experiment name 'N_WGS_000'.

# %% [markdown]
# ## Project specific functions

# %% [markdown]
# This are functions written by the FBI team (ASMU and KLOC).

# %%
#| echo: false
#| output: asis
show_doc(process_sample_sheet)
# Out:
# ---
#
# ### process_sample_sheet
#
# >      process_sample_sheet (dir:pathlib.Path, sample_sheet:str)
#
# This function takes a dir as input, finds a sample sheet in that dir,
#     and return a list list of dicts, one dict per sample
#     from
#
# SampleID        Organism        SupplyingLab
#
#  ecoli1  Ecoli FBI
#
# to
#
# [{'SampleID': 'ecoli1', 'Organism': 'Ecoli', 'SupplyingLab': 'FBI'}]

# %%
#| echo: false
#| output: asis
show_doc(find_fastqs)
# Out:
# ---
#
# ### find_fastqs
#
# >      find_fastqs (dir:pathlib.Path)
#
# This function finds files that end in .fastq.gz in a dir

# %%
#| echo: false
#| output: asis
show_doc(add_fastqs_to_metadata)
# Out:
# ---
#
# ### add_fastqs_to_metadata
#
# >      add_fastqs_to_metadata (metadata:list, fastqs)
#
# This function adds the fastq paths to the metadata.

# %%
#| echo: false
#| output: asis
show_doc(get_stbit)
# Out:
# ---
#
# ### get_stbit
#
# >      get_stbit (stbit:str)
#
# This function that checks if the stbit was provided,
# if not it sets up a default value for it.

# %%
#| echo: false
#| output: asis
show_doc(add_stbit_to_metadata)
# Out:
# ---
#
# ### add_stbit_to_metadata
#
# >      add_stbit_to_metadata (metadata:list, stbit:str)
#
# This function adds the stbit to the metadata.

# %%
#| echo: false
#| output: asis
show_doc(check_db)
# Out:
# ---
#
# ### check_db
#
# >      check_db (dir:pathlib.Path)
#
# This function checks if the database dir exists.

# %%
#| echo: false
#| output: asis
show_doc(make_folder_if_not_exists)
# Out:
# ---
#
# ### make_folder_if_not_exists
#
# >      make_folder_if_not_exists (folder_name)
#
# This function creates output folders if they don't exists.

# %%
#| echo: false
#| output: asis
show_doc(find_dirs)
# Out:
# ---
#
# ### find_dirs
#
# >      find_dirs (path)
#
# This function finds dirs in a path,
# excluding files.

# %%
#| echo: false
#| output: asis
show_doc(find_files)
# Out:
# ---
#
# ### find_files
#
# >      find_files (path)
#
# This function finds files in a path,
# excluding dirs.

# %%
#| echo: false
#| output: asis
show_doc(make_folder_if_not_exists)
# Out:
# ---
#
# ### make_folder_if_not_exists
#
# >      make_folder_if_not_exists (folder_name)
#
# This function creates output folders if they don't exists.
