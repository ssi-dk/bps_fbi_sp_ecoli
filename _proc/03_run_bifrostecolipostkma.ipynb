# %% [markdown]
# ## Run bifrostecolipostkma
# Functions that allow the user to run bifrostecolipostkma.py

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(bifrostecolipostkma)
# Out:
# ---
#
# ### bifrostecolipostkma
#
# >      bifrostecolipostkma (sampleid:str, read1:pathlib.Path,
# >                           read2:pathlib.Path, stbit:str,
# >                           database_path:pathlib.Path, kma_path:pathlib.Path,
# >                           output_dir:pathlib.Path)
#
# A function that generates a command for 1 sample.

# %%
#| echo: false
#| output: asis
show_doc(generate_bifrostecolipostkma_commands)
# Out:
# ---
#
# ### generate_bifrostecolipostkma_commands
#
# >      generate_bifrostecolipostkma_commands (input_dir:pathlib.Path,
# >                                             sample_sheet:str,
# >                                             output_dir:pathlib.Path,
# >                                             database_path:pathlib.Path,
# >                                             kma_path:pathlib.Path)
#
# A function that generates commands for many samples in a folder.

# %%
# #|export
# commands = generate_bifrostecolipostkma_commands(INPUT_DIR, SAMPLE_SHEET, OUTPUT_DIR, DB_PATH, KMA_PATH)
# helpers.write_list_to_file(commands, COMMAND_FILE)
# for command in commands:
#     print(command)
# #     !{command}
# #     helpers.notification(NOTIFICATIONS)

# %% [markdown]
# ## Turn the scripts into a commmand line tool

# %%
#| echo: false
#| output: asis
show_doc(cli)
# Out:
# ---
#
# ### cli
#
# >      cli (input:pathlib.Path=None, sample_sheet:str=None,
# >           output:pathlib.Path=None, db_path:pathlib.Path=None,
# >           kma_path:pathlib.Path=None, command_file:str=None,
# >           execute:bool=True, to_stdout:bool=False, overwrite:bool=False,
# >           config_file:str=None)
#
# This program takes as input a folder containing fastq.gz files and a sample_sheet containing
#
# SampleID        Organism        SupplyingLab
#
# ecoli1  Ecoli FBI
#
# and allows you to run bifrostecolipostkma.py on all Ecoli samples.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | input | Path | None | Path to input folder that contains the .fastq.gz files |
# | sample_sheet | str | None | Name of the sample_sheet file |
# | output | Path | None | Path to the output directory |
# ...
