# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Check required tools are available

# %%
#| echo: false
#| output: asis
show_doc(cli)
# Out:
# ---
#
# ### cli
#
# >      cli (config_file1=None, config_file2=None)
#
# Takes associated config files and runs full QC pipeline which is check for runs not demuxed, demultiplexes them, then runs QC on them
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | config_file1 | NoneType | None | Config file to check raw data vs demux |
# | config_file2 | NoneType | None | Config file to check demux vs qc |
# | **Returns** | **None** |  |  |

# %%
#test
#cli(f"{core.PROJECT_DIR}/config/example_1.env",f"{core.PROJECT_DIR}/config/example_2.env")
